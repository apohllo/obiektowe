// %%
enum SpeedUnit {
    MS, KMH, MA
}

class Speed {
    public double value;
    public SpeedUnit unit;

    public Speed(double value, SpeedUnit unit){
        this.value = value;
        this.unit = unit;
    }
}

class SuperSonicSpeed extends Speed {
    public double value;
    public SpeedUnit unit = SpeedUnit.MA;

    public SuperSonicSpeed(double value){
        super(value, SpeedUnit.MS);
    }
}

Speed speed1 = new Speed(10, SpeedUnit.MS);
speed1.unit;

Speed speed2 = new SuperSonicSpeed(10);
speed2.unit;

SuperSonicSpeed speed3 = new SuperSonicSpeed(10);
speed3.unit;
// Out:
// enum SpeedUnit {
//     MS, KMH, MA
// }
// |  modified enum SpeedUnit
//
//
//
// class Speed {
//     public double value;
//     public SpeedUnit unit;
//
//     public Speed(double value, SpeedUnit unit){
//         this.value = value;
//         this.unit = unit;
//     }
// }
// |  modified class Speed
//
//
//
// class SuperSonicSpeed extends Speed {
//     public double value;
//     public SpeedUnit unit = SpeedUnit.MA;
//
//     public SuperSonicSpeed(double value){
//         super(value, SpeedUnit.MS);
//     }
// }
// |  modified class SuperSonicSpeed
//
//
//
// Speed speed1 = new Speed(10, SpeedUnit.MS);
// speed1 ==> Speed@516be40f
//
// speed1.unit;
// $171 ==> MS
//
//
//
// Speed speed2 = new SuperSonicSpeed(10);
// speed2 ==> SuperSonicSpeed@646be2c3
//
// speed2.unit;
// $173 ==> MS
//
//
//
// SuperSonicSpeed speed3 = new SuperSonicSpeed(10);
// speed3 ==> SuperSonicSpeed@77be656f
//
// speed3.unit;
// $175 ==> MA

// %%
class Speed {
    public double value;
    public SpeedUnit unit;

    public Speed(double value, SpeedUnit unit){
        this.value = value;
        this.unit = unit;
    }
}
class SuperSonicSpeed extends Speed {
    public double value;
    public SpeedUnit unit;

    public SuperSonicSpeed(double value, SpeedUnit unit){
        super(value, unit);
        this.value = value * 10;
        this.unit = unit;
    }
}

Speed speed1 = new Speed(10, SpeedUnit.MS);
speed1.value;
Speed speed2 = new SuperSonicSpeed(10, SpeedUnit.MS);
speed2.value;
SuperSonicSpeed speed3 = new SuperSonicSpeed(10, SpeedUnit.MS);
speed3.value;
// Out:
// class Speed {
//     public double value;
//     public SpeedUnit unit;
//
//     public Speed(double value, SpeedUnit unit){
//         this.value = value;
//         this.unit = unit;
//     }
// }
// |  modified class Speed
//
// class SuperSonicSpeed extends Speed {
//     public double value;
//     public SpeedUnit unit;
//
//     public SuperSonicSpeed(double value, SpeedUnit unit){
//         super(value, unit);
//         this.value = value * 10;
//         this.unit = unit;
//     }
// }
// |  created class SuperSonicSpeed
//
//
//
// Speed speed1 = new Speed(10, SpeedUnit.MS);
// speed1 ==> Speed@6a1aab78
//
// speed1.value;
// $95 ==> 10.0
//
// Speed speed2 = new SuperSonicSpeed(10, SpeedUnit.MS);
// speed2 ==> SuperSonicSpeed@757942a1
//
// speed2.value;
// $97 ==> 10.0
//
// SuperSonicSpeed speed3 = new SuperSonicSpeed(10, SpeedUnit.MS);
// speed3 ==> SuperSonicSpeed@8646db9
//
// speed3.value;
// $99 ==> 100.0
